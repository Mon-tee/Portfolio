# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/customer_loyalty.csv')
data.head()
# Out:
#    Satisfaction  Loyalty
# 0             4    -1.33
# 1             6    -0.28
# 2             5    -0.99
# 3             7    -0.29
# 4             4     1.06

# %%
sns.clustermap(data, cmap='coolwarm')
