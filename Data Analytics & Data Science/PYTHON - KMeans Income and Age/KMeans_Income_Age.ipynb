# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('/content/income.csv')
data.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
data_v2 = data.copy()
data_v2 = data_v2.drop('Name', axis=1)
data_v2.head()
# Out:
#    Age  Income($)
# 0   27      70000
# 1   29      90000
# 2   29      61000
# 3   28      60000
# 4   42     150000

# %%
plt.scatter(data['Age'],data['Income($)'])
plt.xlabel('Age')
plt.ylabel('Income($)')
# Out:
# Text(0, 0.5, 'Income($)')

# %%
x = data_v2.copy()

# %%
kmeans = KMeans(3)
kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
clusters = x.copy()
clusters['cluster_pred']=kmeans.fit_predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(data['Age'],data['Income($)'], c=clusters['cluster_pred'], cmap='rainbow' )
plt.xlabel('Age')
plt.ylabel('Income($)')
# Out:
# Text(0, 0.5, 'Income($)')

# %%
from sklearn import preprocessing
x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-1.35605536, -0.48068427],
#        [-1.00915747, -0.01015907],
#        [-1.00915747, -0.69242061],
#        [-1.18260641, -0.71594687],
#        [ 1.24567876,  1.40141653],
#        [ 0.72533193,  1.51904783],
#        [ 1.07222982,  1.63667914],
#        [ 0.55188299,  1.68373166],
#        [ 0.20498511,  1.54257409],
#        [ 0.03153617,  0.93089133],
#        [ 0.37843405,  1.09557515],
#        [-1.5295043 , -1.06884077],
#        [-1.35605536, -0.99826199],
#        [-1.18260641, -0.92768321],
#        [-1.00915747, -0.9629726 ],
#        [-0.48881065, -0.88063069],
#        [ 0.89878087, -0.59831557],
#        [ 1.07222982, -0.64536809],
#        [ 1.4191277 , -0.62184183],
#        [ 0.72533193, -0.24542167],
#        [ 1.07222982, -0.19836915],
#        [ 0.72533193, -0.76299939]])

# %%
wcss=[]

for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

wcss
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,10),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %%
kmeans_new = KMeans(3)
kmeans_new.fit(x_scaled)
clusters_new = x.copy()
clusters_new['cluster_pred'] = kmeans_new.fit_predict(x_scaled)
clusters_new
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#     Age  Income($)  cluster_pred
# 0    27      70000             1
# 1    29      90000             1
# 2    29      61000             1
# 3    28      60000             1
# 4    42     150000             0
# 5    39     155000             0
# 6    41     160000             0
# 7    38     162000             0
# 8    36     156000             0
# 9    35     130000             0
# 10   37     137000             0
# 11   26      45000             1
# 12   27      48000             1
# 13   28      51000             1
# ...

# %%
plt.scatter(clusters_new['Age'],clusters_new['Income($)'], c=clusters_new['cluster_pred'], cmap='rainbow' )
plt.xlabel('Age')
plt.ylabel('Income($)')
# Out:
# Text(0, 0.5, 'Income($)')
